# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17) 
  
# data (as pandas dataframes) 
X = breast_cancer_wisconsin_diagnostic.data.features 
y = breast_cancer_wisconsin_diagnostic.data.targets 
  
# # metadata 
# print(breast_cancer_wisconsin_diagnostic.metadata) 
  
# # variable information 
# print(breast_cancer_wisconsin_diagnostic.variables)

# %%
X
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      20.29     14.34      135.10  1297.0      0.10030       0.13280
# ..       ...       ...         ...     ...          ...           ...
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  radius3  \
# ...

# %%
y
# Out:
#     Diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
X.info()
X.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   radius1             569 non-null    float64
#  1   texture1            569 non-null    float64
#  2   perimeter1          569 non-null    float64
#  3   area1               569 non-null    float64
#  4   smoothness1         569 non-null    float64
#  5   compactness1        569 non-null    float64
#  6   concavity1          569 non-null    float64
#  7   concave_points1     569 non-null    float64
#  8   symmetry1           569 non-null    float64
#  9   fractal_dimension1  569 non-null    float64
#  10  radius2             569 non-null    float64
#  11  texture2            569 non-null    float64
#  12  perimeter2          569 non-null    float64
#  13  area2               569 non-null    float64
#  14  smoothness2         569 non-null    float64
# ...

# %%
# 범주형 데이터 없음

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y, stratify=y, random_state=42)

# %%
x_train.shape
# Out:
# (426, 30)

# %%
from sklearn.tree import DecisionTreeClassifier
entropy_tree = DecisionTreeClassifier(criterion='entropy')
gini_tree = DecisionTreeClassifier(criterion='gini')
entropy_tree.fit(x_train,y_train)
gini_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# import matplotlib.pyplot as plt
# from sklearn.tree import plot_tree
# plt.figure(figsize=(10,10))
# plot_tree(tree, feature_names=x_train.columns)
# plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, entropy_tree.predict(x_test)))
print(classification_report(y_test, gini_tree.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.94      0.97      0.95        90
#            M       0.94      0.89      0.91        53
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.93      0.93       143
# weighted avg       0.94      0.94      0.94       143
#
#               precision    recall  f1-score   support
#
#            B       0.95      0.98      0.96        90
#            M       0.96      0.91      0.93        53
#
#     accuracy                           0.95       143
#    macro avg       0.95      0.94      0.95       143
# weighted avg       0.95      0.95      0.95       143

# %%
# 클래스 불균형을 처리한 후 진행

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

rds = SMOTE(random_state=42)
x_train_resample,y_train_resample = rds.fit_resample(x_train,y_train)

# %%
tree = DecisionTreeClassifier(criterion = 'gini')
tree.fit(x_train_resample, y_train_resample)
print(classification_report(y_test, tree.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.94      0.97      0.95        90
#            M       0.94      0.89      0.91        53
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.93      0.93       143
# weighted avg       0.94      0.94      0.94       143

# %%
# 주어진 데이터가 얼마나 혼합되어 있는지, 불순도가 낮을수록 해당 노드의 순도가 높다.
# C 클래스 계수
# pi 클래스 i에 속할 확률
# 0에 가까울수록 한가지 클래스에 속할 확률이 높고, 0.5는 골고루
# 클래스 1의 비율 p1 : 6/10 = 0.6
# 크래스 2의 비율 p2 : 4/10 - 0.4
# 결정트리는 각 분기에서 지니 계수를 계산하고 이 값을 가장 크게 감소시키는 방향으로 데이터를 분할

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 정보이득
# 데이터의 부로학실성을 줄이는 정도를 측정
# 분할 전후의 엔트로피 차이 계산해서 정보의 순도(불확실성)가 얼마나 개선되었는지를 나타냄
# 데이터가 0에 가까우면 한쪽 클래스에 치중... 1에 가까우면 고르게 분포
# 정보이득 : 노드를 분할한 다음 엔트로피가 얼마나 감소했는지 계산
# 속성 A에서 S 제외 부분집합

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 클래스1 : 9개 p1 = 9/14 = 0.64
# 클래스2 : 5개 p2 = 5/14 = 0.36
# entropy(s) = -((0.64)log2(0.64) + 0.36log2(0.36) = 0.93

# 데이터를 특성 A로 분할한다고 가정
# 첫번째 그룹 : 클래스 1 4개, 클래스 2 3개
# 두번째 그룹 : 클래스 1 5개, 클래스 2 2개

# %%
# 분할 후 엔트로피의 가중치의 합

# %%
# 정보이득 : 분할 전 엔트로피에서 분할 후 가중치 엔트로피를 뺀 값

# %%
# 속성 A로 데이터를 분할했을 때 정보이득 0.006 정보이득이 클수록 해당 속성으로 데이터를 분할했을 때 얻는 이득이 크다
# 결정트리는 정보이득이 최대가 되는 방향

# %%
# 스케일링이 필요 없다는 장점 있음

# %%
# 분류... 로지스틱 회귀, 최근접 이웃, svm.SVC, 결정트리
# 데이터 - EDA(탐색적 데이터 분석) - 위의 모델중에 적합한 모델 선정 - 평가 - 우수한 모델을 채택

# %% [markdown]
# Car Evaluation

# %%
import pandas as pd
df = pd.read_csv('./car_evaluation.csv')
df.columns = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safty', 'class']
df.head()
# Out:
#   buying  maint doors persons lug_boot safty  class
# 0  vhigh  vhigh     2       2    small   med  unacc
# 1  vhigh  vhigh     2       2    small  high  unacc
# 2  vhigh  vhigh     2       2      med   low  unacc
# 3  vhigh  vhigh     2       2      med   med  unacc
# 4  vhigh  vhigh     2       2      med  high  unacc

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   object
#  1   maint     1727 non-null   object
#  2   doors     1727 non-null   object
#  3   persons   1727 non-null   object
#  4   lug_boot  1727 non-null   object
#  5   safty     1727 non-null   object
#  6   class     1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.isna().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safty       0
# class       0
# dtype: int64

# %%
df.describe()
# Out:
#        buying maint doors persons lug_boot safty  class
# count    1727  1727  1727    1727     1727  1727   1727
# unique      4     4     4       3        3     3      4
# top      high  high     3       4      med   med  unacc
# freq      432   432   432     576      576   576   1209

# %%
df['buying'].unique()
# Out:
# array(['vhigh', 'high', 'med', 'low'], dtype=object)

# %%
df['maint'].unique()
# Out:
# array(['vhigh', 'high', 'med', 'low'], dtype=object)

# %%
df['doors'].unique()
# Out:
# array(['2', '3', '4', '5more'], dtype=object)

# %%
df['persons'].unique()
# Out:
# array(['2', '4', 'more'], dtype=object)

# %%
df['lug_boot'].unique()
# Out:
# array(['small', 'med', 'big'], dtype=object)

# %%
df['safty'].unique()
# Out:
# array(['med', 'high', 'low'], dtype=object)

# %%
df['class'].unique()
# Out:
# array(['unacc', 'acc', 'vgood', 'good'], dtype=object)

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.catplot(data=df, hue='class', vars=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safty'])
# plt.show()

# %%
pd.set_option('future.no_silent_downcasting', True)
df['buying'] = df['buying'].replace({
    'vhigh':3, 'high':2, 'med':1, 'low':0
})
df['maint'] = df['maint'].replace({
    'vhigh':3, 'high':2, 'med':1, 'low':0
})
df['doors'] = df['doors'].replace({
    '2':0, '3':1, '4':2, '5more':3
})
df['persons'] = df['persons'].replace({
    '2':0, '4':1, 'more':2
})
df['lug_boot'] = df['lug_boot'].replace({
    'small':0, 'med':1, 'big':2
})
df['safty'] = df['safty'].replace({
    'med':1, 'high':2, 'low':0
})

# %%
from sklearn.preprocessing import LabelEncoder
df['class'] = LabelEncoder().fit_transform(df['class'])

# %%
df.head()
# Out:
#    buying  maint  doors  persons  lug_boot  safty  class
# 0       3      3      0        0         0      1      2
# 1       3      3      0        0         0      2      2
# 2       3      3      0        0         1      0      2
# 3       3      3      0        0         1      1      2
# 4       3      3      0        0         1      2      2

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# buying
# 2    432
# 1    432
# 0    432
# 3    431
# Name: count, dtype: int64
# maint
# 2    432
# 1    432
# 0    432
# 3    431
# Name: count, dtype: int64
# doors
# 1    432
# 2    432
# 3    432
# 0    431
# Name: count, dtype: int64
# persons
# 1    576
# 2    576
# 0    575
# Name: count, dtype: int64
# lug_boot
# 1    576
# 2    576
# 0    575
# Name: count, dtype: int64
# safty
# 1    576
# 2    576
# 0    575
# Name: count, dtype: int64
# class
# 2    1209
# 0     384
# 1      69
# 3      65
# Name: count, dtype: int64

# %%
# from sklearn.preprocessing import OrdinalEncoder
# od = OrdinalEncoder()

# categorical_columns = X.select_dtypes(include=['object']).columns
# X_od = X.copy()
# X_od[categorical_columns] = od.fit_transform(X[categorical_columns])
# X_od

# %%
df['class'].value_counts() # 클래스 불균형
# Out:
# class
# 2    1209
# 0     384
# 1      69
# 3      65
# Name: count, dtype: int64

# %%
X = df.drop('class', axis=1)
y = df['class']
X.head(), y.head()
# Out:
# (   buying  maint  doors  persons  lug_boot  safty
#  0       3      3      0        0         0      1
#  1       3      3      0        0         0      2
#  2       3      3      0        0         1      0
#  3       3      3      0        0         1      1
#  4       3      3      0        0         1      2,
#  0    2
#  1    2
#  2    2
#  3    2
#  4    2
#  Name: class, dtype: int64)

# %%
X.corr()
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(X.corr())
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,stratify=y,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
knn = KNeighborsRegressor()
lg = LogisticRegression()
dt = DecisionTreeClassifier()

# %%
knn.fit(x_train, y_train)
lg.fit(x_train,y_train)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, dt.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        96
#            1       0.89      1.00      0.94        17
#            2       1.00      0.99      1.00       303
#            3       1.00      0.94      0.97        16
#
#     accuracy                           0.99       432
#    macro avg       0.97      0.97      0.97       432
# weighted avg       0.99      0.99      0.99       432

# %% [markdown]
# 데이터 표준화

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_scaled = ss.fit_transform(X)
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,stratify=y,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %% [markdown]
# classification report

# %%
from sklearn.metrics import f1_score, accuracy_score
# f1_score(y_test, dt.predict)

# %%
model_dict = {
    'dt': DecisionTreeClassifier(),
    'knn': KNeighborsClassifier(),
    'logistic': LogisticRegression(),
    'svm': SVC()
}
result = []
for name, model in model_dict.items():
    model.fit(x_train,y_train)
    result.append(pd.DataFrame(classification_report(y_test, model.predict(x_test),output_dict=True)))

# %%
result_df = pd.concat([result[0].loc[['f1-score']], result[1].loc[['f1-score']], result[2].loc[['f1-score']], result[3].loc[['f1-score']]])
result_df.index = ['dt','knn', 'logistic', 'svm']
result_df
# Out:
#                  0         1         2         3  accuracy  macro avg  \
# dt        0.973822  0.944444  0.995041  1.000000  0.988426   0.978327
# knn       0.958763  0.909091  0.991763  0.933333  0.979167   0.948237
# logistic  0.591716  0.606061  0.908228  0.666667  0.826389   0.693168
# svm       0.948980  0.937500  0.988430  0.967742  0.976852   0.960663
#
#           weighted avg
# dt            0.988518
# knn           0.979012
# logistic      0.817054
# svm           0.976893
