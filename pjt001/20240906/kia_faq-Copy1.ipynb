# %%
pip install selenium webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import re

# %%
url = 'https://www.kia.com/kr/customer-service/center/faq'  
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html,'html.parser')
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko-KR" mode="runtime">
# <head>
# <meta charset="utf-8"/>
# <title>기아 FAQ | 고객 지원  | 기아 공식 사이트</title>
# <meta content="기아 관련 궁금하신 내용은 FAQ 검색을 통해 빠르게 확인해 보세요. 기아에 대한 영업 및 구입, 정비 등은 이메일 및 전화(080-200-2000)로도 문의하실 수 있습니다." name="description"/>
# <meta content="kwp-app-page" name="template"/>
# <meta class="elastic" content="customer-service" name="contenttype"/>
# <meta class="elastic" content="true" name="searchable"/>
# <meta class="elastic" name="noticedate"/>
# <meta class="elastic" name="noticesummary"/>
# <meta class="elastic" name="noticetitle"/>
# <meta content="initial-scale=1.0,user-scalable=no,maximum-scale=1,width=device-width" name="viewport"/>
# <meta content="Summary" name="twitter:card"/>
# <meta content="기아 FAQ | 고객 지원" name="twitter:title"/>
# <meta content="기아 FAQ 페이지에 오신 것을 환영합니다. 기아 관련 궁금하신 내용은 FAQ 검색을 통해 빠르게 확인해 보세요. 기아에 대한 영업 및 구입, 정비 등은 이메일 및 전화(080-200-2000)로도 문의하실 수 있습니다." name="twitter:description"/>
# ...

# %%
faq = soup.select('#contents > div > div.container.responsivegrid.aem-GridColumn.aem-GridColumn')
# faq = soup.select('#contents > div > div.container.responsivegrid.aem-GridColumn.aem-GridColumn--default--12 > div > div > div.cmp-accor-faq.cmp-content__section > div')
faq
# Out:
# [<div class="container responsivegrid aem-GridColumn aem-GridColumn--default--12"><!--
#  Copyright 2017 Adobe Systems Incorporated
#
#  Licensed under the Apache License, Version 2.0 (the "License");
#  you may not use this file except in compliance with the License.
#  You may obtain a copy of the License at
#
#      http://www.apache.org/licenses/LICENSE-2.0
#
#  Unless required by applicable law or agreed to in writing, software
#  distributed under the License is distributed on an "AS IS" BASIS,
#  WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#  See the License for the specific language governing permissions and
#  limitations under the License.
#  -->
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Optional: Set up Chrome options if needed
chrome_options = Options()

service = Service(ChromeDriverManager().install())
wd = webdriver.Chrome(service=service, options=chrome_options)

# Navigate to the desired URL
wd.get('https://www.kia.com/kr/customer-service/center/faq')

# Maximize the browser window
wd.maximize_window()

# Your additional code for interaction or scraping would go here

# Close the browser after use
# wd.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Chrome 드라이버 경로 설정
chrome_driver_path = '/path/to/chromedriver'  # 자신의 chromedriver 경로로 변경

# Chrome 옵션 설정
chrome_options = Options()
chrome_options.add_argument('--headless')  # 브라우저 창을 열지 않고 백그라운드에서 실행 (옵션)

# 웹 드라이버 설정
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# 페이지 열기
url = 'https://www.kia.com/kr/customer-service/center/faq'
driver.get(url)

try:
    # 요소가 로드될 때까지 대기
    driver.implicitly_wait(10)

    # 숨겨진 요소 찾기 (경로는 페이지의 실제 구조에 따라 조정 필요)
    element = driver.find_element(By.CSS_SELECTOR, '.accordion-item0-button')
    
    # 요소의 텍스트 출력
    print("Found element:", element.text)
    
    # 요소의 속성 출력
    print("Element attributes:", element.get_attribute('outerHTML'))
    
except Exception as e:
    print("Error:", e)

finally:
    # 드라이버 종료
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\pyconda\Lib\site-packages\selenium\webdriver\common\driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: /path/to/chromedriver
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[26], line 15
#      13 # 웹 드라이버 설정
#      14 service = Service(chrome_driver_path)
# ---> 15 driver = webdriver.Chrome(service=service, options=chrome_options)
#      17 # 페이지 열기
#      18 url = 'https://www.kia.com/kr/customer-service/center/faq'
#
# ...

# %%
faq_list = []
category = []
question = []
answer = []

for i in range(0,len(faq),2):
    faq = soup.select('#accordion-item0-button')
    temp = faq[i].text.strip().split(']')
    k, q = temp[0][1:],temp[1]
    a = faq[i+1].text.strip()

    # 정규 표현식 개선: 숫자, 한글, 공백, 특수 문자 등을 더 많이 포함
    re_a = re.findall(r'[가-힣0-9\s\.\,\?\!]+', a)
    an = ' '.join(re_a).replace('\xa0', '').replace('\n', '').replace('\t', '')
    
    category.append(k)
    question.append(q)
    answer.append(an)

# %%
selenium_el = wd.find_element(By.XPATH,'//*[@id="tab-list"]/li[3]/button')
selenium_el.click()

# %%
result = []
faq_list = []
category = []
question = []
answer = []

for j in range(2,8):
    try:
        selenium_el = wd.find_element(By.XPATH,f'//*[@id="tab-list"]/li[{j}]/button')
selenium_el.click()
        
        html = wd.page_source  #  현재 페이지 정보를 html로 변환
        soup = BeautifulSoup(html, 'html.parser') # html 정보를 파싱
        
        faq = soup.select('#accordion-specification')
        for i in range(0,len(faq),2):
            temp = faq[i].text.strip().split(']')
            k, q = temp[0][1:],temp[1]
            a = faq[i+1].text.strip()
        
            # 정규 표현식 개선: 숫자, 한글, 공백, 특수 문자 등을 더 많이 포함
            re_a = re.findall(r'[가-힣0-9\s\.\,\?\!]+', a)
            an = ' '.join(re_a).replace('\xa0', '').replace('\n', '').replace('\t', '')
            
            category.append(k)
            question.append(q)
            answer.append(an)
            
    except Exception as e:
        print(i)
        print(j)

# %%
import pandas as pdS

data = {
    'category':category,
    'question' : question,
    'answer': answer}

df = pd.DataFrame(data)
df
# Out:
#        category                               question  \
# 0          구매관련             근저당 설정 해지 방법 및 절차를 알고싶습니다.
# 1          구매관련           저공해 증명서 재발급 철차 및 장소를 알고싶습니다.
# 2          구매관련                재고차 구입 조건시 할인율을 알고싶습니다.
# 3          구매관련           신차 구입시 출고 예정일 확인 방법을 알고싶습니다.
# 4          구매관련                  할부금 중도 상환 방법을 알고싶습니다.
# ..          ...                                    ...
# 123  OnlineShop                           선포인트가 무엇인가요?
# 124  OnlineShop                온라인 구매를 위해 사전에 준비할 것들은?
# 125  OnlineShop   개명했는데 휴대폰 인증에서 에러가 나는 경우는 어떻게 해야하나요?
# 126  OnlineShop            본인 명의 휴대폰이 아니면 서비스이용이 불가한지?
# 127  OnlineShop                     비회원은 온라인 구매가 불가한지?
#
#                                                 answer
# 0    자동차 근저당 설정 해지는 할부를 진행한 할부사의 지점을 방문하여 근저당 설정 해지...
# 1    저공해 자동차 증명서는 차량 구입을 담당한 전시장을 통해 재 발급이 가능합니다.차량...
# 2                       쉐보레 전시장을 통해 자세한 상담 받아주시기 바랍니다.
# 3    출고예정일은 고객님께서 선택하신 차종, 옵션, 색상 등에 따라 다소 차이가 있습니다...
# ...

# %%
from sqlalchemy import create_engine
username = 'root'
password = '1234'
host = 'localhost'
database = 'mydatabase'

engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}/{database}')

df.to_sql('qna_che', con=engine, if_exists='append', index=False)

engine.dispose()
