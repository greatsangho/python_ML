# %%
# json형식의 반환값을 json 객체로 변환
import pandas as pd
import os 
import sys
import urllib.request
import json
from bs4 import BeautifulSoup  # pip install bs4
import xml.etree.ElementTree as ET

# 잡코리아 FAQ
result = []
for i in range(1,6):
    url = f'https://www.jobkorea.co.kr/help/faq/user?tab={i}'    
    html = urllib.request.urlopen(url)
    soup = BeautifulSoup(html,'html.parser')    
    li_lists = soup.select('#content > div > div.faqWrap > div.tabSearchList > ul > li')    
    
    for data in li_lists:    
        temp = data.select('span.tabSearchListTitleWrap')[0].text.split(']')
        temp[0] = temp[0][1:]
        result.append(temp)    
result
# Out:
# [['회원가입·로그인', '로그인 상태 유지란?'],
#  ['보안 서비스', 'IP 보안 사용방법이 어떻게 되나요?'],
#  ['보안 서비스', 'IP 보안이란?'],
#  ['회원가입·로그인', '잡코리아를 탈퇴하면 패밀리사이트도 이용할 수 없나요?'],
#  ['회원가입·로그인', '자동 로그아웃 현상이 자주 반복됩니다. 어떻게 하나요?'],
#  ['회원가입·로그인', '회원탈퇴는 어떻게 하나요?'],
#  ['회원가입·로그인', '로그인이 안돼요. 어떻게 하나요?'],
#  ['회원가입·로그인', '발급받은 아이핀 ID와 비밀번호를 분실했어요. 어떻게 하나요?'],
#  ['회원가입·로그인', '하나의 아이핀 발급으로 다른 웹사이트에서도 아이핀 서비스 이용이 가능한가요?'],
#  ['회원가입·로그인', '아이핀을 발급받으려면 이용자가 별도의 비용을 부담해야 하나요?'],
#  ['회원가입·로그인', '아이핀(I-Pin)이란 무엇인가요?'],
#  ['회원가입·로그인', '개명이 되었는데 이름을 어떻게 변경하나요?'],
#  ['회원가입·로그인', '회원정보 중에 생년월일과 성별이 잘못 기입되었습니다. 어떻게 하나요?'],
#  ['회원가입·로그인', '소셜 로그인으로 잡코리아를 이용하고 있는데 탈퇴하면 어떻게 되나요?'],
#  ['회원가입·로그인', '소셜 로그인으로 잡코리아를 이용하고 있는데 연동한 소셜서비스를 탈퇴하면 어떻게 되나요?'],
#  ['보안 서비스', '보안 프로그램 수동 설치는 어떻게 하나요?'],
#  ['보안 서비스', '수동 설치를 통하여 보안 프로그램을 설치했는데, 삭제는 어떻게 하나요?'],
#  ['보안 서비스', '웹페이지를 통해서 자동으로 보안 프로그램이 설치되었는데, 삭제는 어떻게 하나요?'],
#  ['보안 서비스', '보안 프로그램을 설치하지 않고, 잡코리아 사이트를 이용할 수는 없나요?'],
#  ['회원가입·로그인', '휴면 ID 해제 안내를 받았습니다. 휴면 ID 해제된 건가요?'],
# ...

# %%
# 사람인 FAQ
url = 'https://www.saramin.co.kr/zf_user/help/help-word/main'
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html,'html.parser')    
tit_list_help = soup.select('h2.tit_list_help')
tit_list_help[0].select('strong')[0].text[2:].strip()
# Out:
# '이력서 등록 / 관리'

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n <head>\n  <title>\n   사람인 고객센터 | 도움말 - 사람인\n  </title>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="ko-KR" http-equiv="Content-Language"/>\n  <meta content="86455485e27cab6986d130e4c3b90c5b516820d1" name="naver-site-verification"/>\n  <meta content="사람인 고객센터 | 도움말 - 사람인" name="title"/>\n  <meta content="사람인" name="writer"/>\n  <meta content="고객센터, 사람인, saramin, 사람인 고객센터, 공지사항, 도움말, 이벤트, FAQ, 문의내역" name="keywords"/>\n  <meta content="사람인 고객센터 | 도움말 페이지 입니다. 사람인에서 더 많은 정보를 확인해보세요." name="description"/>\n  <meta content="nosublinks" name="naver"/>\n  <meta content="사람인 고객센터 | 도움말 - 사람인" property="og:title"/>\n  <meta content="사람인" property="og:site_name"/>\n  <meta content="https://www.saramin.co.kr/zf_user/help/help-word/main" property="og:url"/>\n  <meta content="website" property="og:type"/>\n  <meta content="ko_KR" property="og:locale"/>\n  <met
# ...
