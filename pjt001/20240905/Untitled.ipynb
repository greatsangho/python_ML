# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_excel('2024년_07월_자동차_등록자료_통계.xlsx', sheet_name=)
df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2         <      자동차       통계표 Unnamed: 6  \
# 0       조회년월:    2024.07        NaN       NaN      NaN       NaN        NaN
# 1          차종         차종         승용       NaN      NaN       NaN         승합
# 2         용도별        NaN         관용       자가용      영업용         계         관용
# 3         시도별        NaN        NaN       NaN      NaN       NaN        NaN
# 4          서울        NaN       4742   2654961   117223   2776926       3801
# 5          부산        NaN       1813   1179091   130625   1311529       1276
# 6          대구        NaN       1107   1035150    29981   1066238       1027
# 7          인천        NaN       1735   1266681   226155   1494571       1155
# 8          광주        NaN        916    599209    13876    614001        604
# 9          대전        NaN        693    595066    29352    625111        554
# 10         울산        NaN        760    506200     7451    514411        512
# ...
